# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# Invoke-WebRequest -Uri "https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv" -OutFile "car_fuel_efficiency_2026.csv"

# %%
df=pd.read_csv('car_fuel_efficiency_2026.csv')
df

# %%
df.shape
# Out:
# (10000, 11)

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %%
(df.isnull().sum() > 0).sum()
# Out:
# np.int64(2)

# %%
df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
df.groupby('origin')['fuel_efficiency_mpg'].max()
# Out:
# origin
# Asia      41.2
# Europe    39.4
# USA       38.2
# Name: fuel_efficiency_mpg, dtype: float64

# %%
median_before = df['horsepower'].median()
print(f"Median before: {median_before}")
# Out:
# Median before: 254.0

# %%
mode_val = df['horsepower'].mode()[0]
print(f"Most frequent value (Mode): {mode_val}")
# Out:
# Most frequent value (Mode): 252.0

# %%
df_filled = df['horsepower'].fillna(mode_val)
df_filled
# Out:
# 0       243.0
# 1       272.0
# 2       267.0
# 3       258.0
# 4       304.0
#         ...
# 9995    271.0
# 9996    244.0
# 9997    267.0
# 9998    270.0
# 9999    295.0
# Name: horsepower, Length: 10000, dtype: float64

# %%
median_after = df_filled.median()
print(f"Median after: {median_after}")
# Out:
# Median after: 252.0

# %%
print(f"Has it changed? {median_before != median_after}")
# Out:
# Has it changed? True

# %%
import numpy as np

# %%
df_asia = df[df['origin'] == 'Asia'][['vehicle_weight', 'model_year']]

# %%
X = df_asia.iloc[:7].values

# %%
XTX = X.T.dot(X)

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
w = XTX_inv.dot(X.T).dot(y)

# %%
w_sum = w.sum()
print("Result:", w_sum)
print("Rounded result:", round(w_sum, 4))
# Out:
# Result: 0.36919696904925486
# Rounded result: 0.3692
